# %%
# Import our dependencies
import pandas as pd
import sqlalchemy
import psycopg2
#from config import db_password
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder

import tensorflow as tf

# %%
# Read Bronx Sales Prices
file_path1 = "Resources/2020_bronx_sales_prices (1).csv"
bronx_df = pd.read_csv(file_path1, index_col=0)
bronx_df = bronx_df.dropna()
bronx_df.head()
# Out:
#         NEIGHBORHOOD    BUILDING CLASS CATEGORY  NUMBER OF SALES  \
# BOROUGH
# BRONX       BATHGATE    01 ONE FAMILY DWELLINGS              5.0
# BRONX       BATHGATE    02 TWO FAMILY DWELLINGS              9.0
# BRONX       BATHGATE  03 THREE FAMILY DWELLINGS              4.0
# BRONX     BAYCHESTER    01 ONE FAMILY DWELLINGS             91.0
# BRONX     BAYCHESTER    02 TWO FAMILY DWELLINGS            116.0
#
#         MINIMUM SALE PRICE AVERAGE SALE PRICE MEDIAN SALE PRICE  \
# BOROUGH
# BRONX              275,000            404,600           458,000
# BRONX              404,586            568,495           625,000
# BRONX              325,000            628,625           645,000
# BRONX              200,000            469,167           475,000
# BRONX              225,000            652,295           665,000
#
#         MAXIMUM SALE PRICE
# BOROUGH
# BRONX              526,000
# BRONX              750,000
# BRONX              899,500
# BRONX            1,135,173
# ...

# %%
# Read Brooklyn sales prices 
file_path2 = "Resources/2020_brooklyn_sales_prices.csv"
brooklyn_df = pd.read_csv(file_path2, index_col=0)
brooklyn_df = brooklyn_df.dropna()
brooklyn_df.head()
# Out:
#          NEIGHBORHOOD    BUILDING CLASS CATEGORY  NUMBER OF SALES  \
# BOROUGH
# BROOKLYN   BATH BEACH    01 ONE FAMILY DWELLINGS             18.0
# BROOKLYN   BATH BEACH    02 TWO FAMILY DWELLINGS             44.0
# BROOKLYN   BATH BEACH  03 THREE FAMILY DWELLINGS             17.0
# BROOKLYN    BAY RIDGE    01 ONE FAMILY DWELLINGS            101.0
# BROOKLYN    BAY RIDGE    02 TWO FAMILY DWELLINGS            101.0
#
#          MINIMUM SALE PRICE AVERAGE SALE PRICE MEDIAN SALE PRICE  \
# BOROUGH
# BROOKLYN            740,000            900,162           825,455
# BROOKLYN            300,000            970,654           965,000
# BROOKLYN            364,252          1,405,408         1,380,000
# BROOKLYN            350,000          1,193,506         1,100,000
# BROOKLYN            350,000          1,211,090         1,200,000
#
#          MAXIMUM SALE PRICE
# BOROUGH
# BROOKLYN          1,300,000
# BROOKLYN          1,400,000
# BROOKLYN          2,117,960
# BROOKLYN          3,250,000
# ...

# %%
# Read Manhattan sales prices
file_path3 = "Resources/2020_manhattan_sales_prices.csv"
manhattan_df = pd.read_csv(file_path3, index_col=0)
manhattan_df = manhattan_df.dropna()
manhattan_df.head()
# Out:
#             NEIGHBORHOOD    BUILDING CLASS CATEGORY  NUMBER OF SALES  \
# BOROUGH
# MANHATTAN  ALPHABET CITY  03 THREE FAMILY DWELLINGS              1.0
# MANHATTAN        CHELSEA    01 ONE FAMILY DWELLINGS              2.0
# MANHATTAN        CHELSEA    02 TWO FAMILY DWELLINGS              2.0
# MANHATTAN        CHELSEA  03 THREE FAMILY DWELLINGS              1.0
# MANHATTAN        CLINTON    01 ONE FAMILY DWELLINGS              1.0
#
#           MINIMUM SALE PRICE AVERAGE SALE PRICE MEDIAN SALE PRICE  \
# BOROUGH
# MANHATTAN          4,350,000          4,350,000         4,350,000
# MANHATTAN          6,000,000         10,499,950        10,499,950
# MANHATTAN          4,150,000          5,325,000         5,325,000
# MANHATTAN          4,100,000          4,100,000         4,100,000
# MANHATTAN          7,500,000          7,500,000         7,500,000
#
#           MAXIMUM SALE PRICE
# BOROUGH
# MANHATTAN          4,350,000
# MANHATTAN         14,999,900
# MANHATTAN          6,500,000
# ...

# %%
# Read Queens sales prices
file_path4 = "Resources/2020_queens_sales_prices.csv"
queens_df = pd.read_csv(file_path4, index_col=0)
queens_df = queens_df.dropna()
queens_df.head()
# Out:
#                NEIGHBORHOOD    BUILDING CLASS CATEGORY  NUMBER OF SALES  \
# BOROUGH
# QUEENS   AIRPORT LA GUARDIA    01 ONE FAMILY DWELLINGS              1.0
# QUEENS              ARVERNE    01 ONE FAMILY DWELLINGS             26.0
# QUEENS              ARVERNE    02 TWO FAMILY DWELLINGS             53.0
# QUEENS              ARVERNE  03 THREE FAMILY DWELLINGS             17.0
# QUEENS              ASTORIA    01 ONE FAMILY DWELLINGS             34.0
#
#         MINIMUM SALE PRICE AVERAGE SALE PRICE MEDIAN SALE PRICE  \
# BOROUGH
# QUEENS             584,569            584,569           584,569
# QUEENS             210,000            398,630           425,000
# QUEENS             250,000            615,616           630,000
# QUEENS             230,000         10,749,941        13,950,000
# QUEENS             367,500            918,000           920,000
#
#         MAXIMUM SALE PRICE
# BOROUGH
# QUEENS             584,569
# QUEENS             565,000
# QUEENS             995,000
# ...

# %%
# Read Staten Island sales prices 
file_path5 = "Resources/2020_staten_island_sales_prices.csv"
staten_island_df = pd.read_csv(file_path5, index_col=0)
staten_island_df = staten_island_df.dropna()
staten_island_df.head()
# Out:
# C:\Users\esteg\AppData\Local\Temp/ipykernel_16300/723284103.py:3: DtypeWarning: Columns (16383) have mixed types. Specify dtype option on import or set low_memory=False.
#   staten_island_df = pd.read_csv(file_path5, index_col=0)
# Empty DataFrame
# ...

# %% [markdown]
# # Machine Learning
# Linear Regression Model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16300/829452272.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#
# NameError: name 'X' is not defined
